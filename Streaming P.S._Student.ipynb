# %%
from IPython.display import display, HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
# !pip install pyspark
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=f7351f0ff1545d852c7d7dd564ab19686a7e60746ba1f43900733d3f04446c8b
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
spark = SparkSession.builder\
.master ("local")\
.appName ("Colab")\
.config ('spark.ui.port', '4050')\
.getOrCreate ()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://6007d2742380:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Create the schema of the streamed files (check the column names and types from the CSV files)

# %%
schema = StructType([
    StructField("ID", IntegerType(), True),
    StructField("Date", StringType(), True),
    StructField("Open", DoubleType(), True),
    StructField("High", DoubleType(), True),
    StructField("Low", DoubleType(), True),
    StructField("Close", DoubleType(), True),
    StructField("Adj Close", DoubleType(), True),
    StructField("Volume", DoubleType(), True)
])

# %% [markdown]
# ### Create the dataframe by reading the stream using format "csv" and the schema you created.

# %%
df = spark.readStream.format("csv").schema(schema).load("/content/drive/MyDrive/InputData")

# %% [markdown]
# ### Make sure the dataframe is streaming the files from the folder

# %%
df.isStreaming
# Out:
# True

# %% [markdown]
# ### Create a stream writer into memory and specify the query name "stock:

# %%
steamWriter1 = df.writeStream.outputMode("append") \
    .format("memory")\
    .queryName('stock')

# %% [markdown]
# ### Start the write stream and make sure it works (read all columns from the table)

# %%
#query1.stop()

# %%
query1= steamWriter1.start()
df2 = spark.sql('SELECT * FROM stock')
df2.show()
# Out:
# +---+----+----+----+---+-----+---------+------+
# |   |Date|Open|High|Low|Close|Adj Close|Volume|
# +---+----+----+----+---+-----+---------+------+
# +---+----+----+----+---+-----+---------+------+

# %%
df2 = spark.sql('SELECT * FROM stock')
df2.show()
# Out:
# +----+----------+------------+------------+------------+------------+------------+--------+
# |    |      Date|        Open|        High|         Low|       Close|   Adj Close|  Volume|
# +----+----------+------------+------------+------------+------------+------------+--------+
# |NULL|      Date|        NULL|        NULL|        NULL|        NULL|        NULL|    NULL|
# | 120|2000-06-20|22817.900391|23102.199219|21680.599609|22320.300781|21092.632813| 34466.0|
# | 121|2000-06-21|21893.800781|22675.699219|21680.599609|22675.699219|21428.484375| 68651.0|
# | 122|2000-06-22|23386.599609|23386.599609|     22462.5|23031.099609|21764.335938| 97209.0|
# | 123|2000-06-23|22107.099609|24097.400391|22107.099609|     22889.0|21630.052734|199483.0|
# | 124|2000-06-26|23102.199219|     24168.5|22569.099609|24026.300781|22704.796875|121969.0|
# | 125|2000-06-27|24026.300781|25519.099609|     23742.0|24026.300781|22704.796875|113809.0|
# | 126|2000-06-28|23884.199219|24666.099609|23884.199219|24666.099609|23309.408203| 86236.0|
# | 127|2000-06-29|25234.699219|25234.699219|23919.699219|24239.599609|22906.365234| 45299.0|
# | 128|2000-06-30|24523.900391|25092.599609|     23742.0|24879.300781|23510.880859| 76670.0|
# | 129|2000-07-03|24239.599609|25590.199219|24239.599609|25092.599609|23712.449219| 63306.0|
# | 130|2000-07-04|25767.900391|26087.699219|25234.699219|     25448.0|24048.302734| 45299.0|
# | 131|2000-07-05|     25448.0|25590.199219|24523.900391|     25448.0|24048.302734| 48816.0|
# | 132|2000-07-06|25519.099609|27367.300781|25128.099609|26585.300781|25123.048828|178662.0|
# | 133|2000-07-07|27011.800781|     27154.0|     26301.0|27011.800781|25526.091797|104103.0|
# | 134|2000-07-10|27722.699219|27722.699219|26443.199219|27011.800781|25526.091797|101570.0|
# | 135|2000-07-11|27011.800781|27011.800781|26372.099609|26514.199219|25055.859375| 73716.0|
# | 136|2000-07-12|26514.199219|27935.900391|26087.699219|26869.699219|25391.804688|139976.0|
# | 137|2000-07-13|26869.699219|26940.800781|     26301.0|26407.599609|24955.119141| 64994.0|
# | 138|2000-07-14|25945.599609|26407.599609|25341.400391|25803.400391|24384.154297| 75404.0|
# +----+----------+------------+------------+------------+------------+------------+--------+
# only showing top 20 rows

# %% [markdown]
# ### Remove the first row from the data (hint: drop the rows where ALL values are null), then add a new column "diff", which is the difference between high and low columns

# %%
df_2 = df.na.drop(how='any')

df3 = df_2.withColumn("Diff", df_2["High"] - df_2["Low"])

# %% [markdown]
# ### Create a new write stream using the new generated dataframe and call the generated table "modified_data"

# %%
steamWriter2 = df3.writeStream.outputMode("append").format("memory").queryName('modified_data')

# %%
query2 = steamWriter2.start()
df5 = spark.sql('SELECT * FROM modified_data')
df5.show()
# Out:
# +---+----+----+----+---+-----+---------+------+----+
# |   |Date|Open|High|Low|Close|Adj Close|Volume|Diff|
# +---+----+----+----+---+-----+---------+------+----+
# +---+----+----+----+---+-----+---------+------+----+

# %%
df5 = spark.sql('SELECT * FROM modified_data')
df5.show()
# Out:
# +---+----------+------------+------------+------------+------------+------------+--------+------------------+
# |   |      Date|        Open|        High|         Low|       Close|   Adj Close|  Volume|              Diff|
# +---+----------+------------+------------+------------+------------+------------+--------+------------------+
# |120|2000-06-20|22817.900391|23102.199219|21680.599609|22320.300781|21092.632813| 34466.0|1421.5996099999975|
# |121|2000-06-21|21893.800781|22675.699219|21680.599609|22675.699219|21428.484375| 68651.0| 995.0996099999975|
# |122|2000-06-22|23386.599609|23386.599609|     22462.5|23031.099609|21764.335938| 97209.0| 924.0996090000008|
# |123|2000-06-23|22107.099609|24097.400391|22107.099609|     22889.0|21630.052734|199483.0|1990.3007819999984|
# |124|2000-06-26|23102.199219|     24168.5|22569.099609|24026.300781|22704.796875|121969.0|1599.4003909999992|
# |125|2000-06-27|24026.300781|25519.099609|     23742.0|24026.300781|22704.796875|113809.0|1777.0996090000008|
# |126|2000-06-28|23884.199219|24666.099609|23884.199219|24666.099609|23309.408203| 86236.0| 781.9003900000025|
# |127|2000-06-29|25234.699219|25234.699219|23919.699219|24239.599609|22906.365234| 45299.0|            1315.0|
# |128|2000-06-30|24523.900391|25092.599609|     23742.0|24879.300781|23510.880859| 76670.0|1350.5996090000008|
# |129|2000-07-03|24239.599609|25590.199219|24239.599609|25092.599609|23712.449219| 63306.0|1350.5996099999975|
# |130|2000-07-04|25767.900391|26087.699219|25234.699219|     25448.0|24048.302734| 45299.0|             853.0|
# |131|2000-07-05|     25448.0|25590.199219|24523.900391|     25448.0|24048.302734| 48816.0| 1066.298827999999|
# |132|2000-07-06|25519.099609|27367.300781|25128.099609|26585.300781|25123.048828|178662.0| 2239.201172000001|
# |133|2000-07-07|27011.800781|     27154.0|     26301.0|27011.800781|25526.091797|104103.0|             853.0|
# |134|2000-07-10|27722.699219|27722.699219|26443.199219|27011.800781|25526.091797|101570.0|            1279.5|
# |135|2000-07-11|27011.800781|27011.800781|26372.099609|26514.199219|25055.859375| 73716.0|  639.701172000001|
# |136|2000-07-12|26514.199219|27935.900391|26087.699219|26869.699219|25391.804688|139976.0| 1848.201172000001|
# |137|2000-07-13|26869.699219|26940.800781|     26301.0|26407.599609|24955.119141| 64994.0| 639.8007810000017|
# |138|2000-07-14|25945.599609|26407.599609|25341.400391|25803.400391|24384.154297| 75404.0|1066.1992180000016|
# |139|2000-07-17|25803.400391|25803.400391|25803.400391|25803.400391|24384.154297|     0.0|               0.0|
# +---+----------+------------+------------+------------+------------+------------+--------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### Write the generated data into files instead of the memory.

# %%
csvWriter3 = df3.writeStream.outputMode("append").format("csv").option("path", "/content/drive/MyDrive/OutputData")\
.option("checkpointLocation", "chkpnt")

# %%
query3 = csvWriter3.start()

# %% [markdown]
# ### Stop the query. Now, try reading the generated files into a normal dataframe
# - Create a schema and use it to read the data.
# - Show the output.

# %%
query1.stop()

# %%
schema2 = StructType([
    StructField("", IntegerType(), True),
    StructField("Date", StringType(), True),
    StructField("Open", DoubleType(), True),
    StructField("High", DoubleType(), True),
    StructField("Low", DoubleType(), True),
    StructField("Close", DoubleType(), True),
    StructField("Adj Close", DoubleType(), True),
    StructField("Volume", DoubleType(), True),
    StructField('Diff', DoubleType(), True)])

# %%
df6 = spark.read.format("csv").schema(schema2).load("/content/drive/MyDrive/OutputData")

# %%
df6.show()
# Out:
# +---+----------+------------+------------+------------+------------+------------+--------+------------------+
# |   |      Date|        Open|        High|         Low|       Close|   Adj Close|  Volume|              Diff|
# +---+----------+------------+------------+------------+------------+------------+--------+------------------+
# |120|2000-06-20|22817.900391|23102.199219|21680.599609|22320.300781|21092.632813| 34466.0|1421.5996099999975|
# |121|2000-06-21|21893.800781|22675.699219|21680.599609|22675.699219|21428.484375| 68651.0| 995.0996099999975|
# |122|2000-06-22|23386.599609|23386.599609|     22462.5|23031.099609|21764.335938| 97209.0| 924.0996090000008|
# |123|2000-06-23|22107.099609|24097.400391|22107.099609|     22889.0|21630.052734|199483.0|1990.3007819999984|
# |124|2000-06-26|23102.199219|     24168.5|22569.099609|24026.300781|22704.796875|121969.0|1599.4003909999992|
# |125|2000-06-27|24026.300781|25519.099609|     23742.0|24026.300781|22704.796875|113809.0|1777.0996090000008|
# |126|2000-06-28|23884.199219|24666.099609|23884.199219|24666.099609|23309.408203| 86236.0| 781.9003900000025|
# |127|2000-06-29|25234.699219|25234.699219|23919.699219|24239.599609|22906.365234| 45299.0|            1315.0|
# |128|2000-06-30|24523.900391|25092.599609|     23742.0|24879.300781|23510.880859| 76670.0|1350.5996090000008|
# |129|2000-07-03|24239.599609|25590.199219|24239.599609|25092.599609|23712.449219| 63306.0|1350.5996099999975|
# |130|2000-07-04|25767.900391|26087.699219|25234.699219|     25448.0|24048.302734| 45299.0|             853.0|
# |131|2000-07-05|     25448.0|25590.199219|24523.900391|     25448.0|24048.302734| 48816.0| 1066.298827999999|
# |132|2000-07-06|25519.099609|27367.300781|25128.099609|26585.300781|25123.048828|178662.0| 2239.201172000001|
# |133|2000-07-07|27011.800781|     27154.0|     26301.0|27011.800781|25526.091797|104103.0|             853.0|
# |134|2000-07-10|27722.699219|27722.699219|26443.199219|27011.800781|25526.091797|101570.0|            1279.5|
